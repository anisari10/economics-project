# %% [markdown]
# <a href="https://colab.research.google.com/github/anisari10/economics-project/blob/main/economics_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = pd.read_excel (r'/gdi.xlsx') 
df = pd.DataFrame(data, columns=['Country','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019'])
arr=[]
for i in range(df.shape[0]):
  inner_arr=[]
  for row in df.loc[i]:
    # print(row)
    inner_arr.append(row)
  arr.append(inner_arr)  
main_data=[]
data_2 = pd.read_excel(r'/trend_analysis_dev.xlsx', sheet_name="developing")
df_2 = pd.DataFrame(data_2, columns=['Countries'])

# print(len(arr))
main_data=dict()
for i in range(df_2.shape[0]):
  key=0
  for j in range(len(arr)):
    value=[]
    name=[]
    if arr[j][0] == df_2.Countries[i]:
      name.append(arr[j][0])
      k=1
      key=1
      while k<=10 :
        value.append(arr[j][k])
        k=k+1
        key=1
      if key==1 :
        main_data[arr[j][0]]=value
print(main_data)
# Out:
# {'Algeria': [0.83, 0.834, 0.836, 0.839, 0.836, 0.854, 0.855, 0.861, 0.86, 0.858], 'Argentina': [0.993, 0.992, 0.992, 0.994, 0.992, 0.993, 0.994, 0.993, 0.992, 0.993], 'Bahrain': [0.973, 0.971, 0.944, 0.946, 0.944, 0.938, 0.933, 0.936, 0.936, 0.922], 'Bangladesh': [0.848, 0.838, 0.845, 0.866, 0.877, 0.885, 0.891, 0.895, 0.896, 0.904], 'Barbados': [0.991, 0.991, 0.992, 0.992, 0.99, 0.991, 0.991, 0.991, 0.992, 0.992], 'Benin': [0.828, 0.829, 0.833, 0.84, 0.842, 0.86, 0.859, 0.845, 0.855, 0.855], 'Botswana': [0.977, 0.981, 0.982, 0.99, 0.992, 0.993, 0.994, 0.995, 0.995, 0.998], 'Brazil': [0.999, 0.992, 0.995, 0.995, 0.995, 0.996, 0.996, 0.995, 0.995, 0.993], 'Brunei Darussalam': [0.962, 0.968, 0.972, 0.975, 0.976, 0.978, 0.978, 0.978, 0.978, 0.981], 'Burkina Faso': [0.833, 0.839, 0.848, 0.856, 0.863, 0.868, 0.872, 0.874, 0.865, 0.867], 'Cameroon': [0.854, 0.861, 0.865, 0.866, 0.835, 0.868, 0.867, 0.869, 0.87, 0.864], 'Chad': [0.757, 0.767, 0.769, 0.77, 0.771, 0.774, 0.772, 0.773, 0.773, 
# ...

# %%
file_data= pd.DataFrame(main_data)
file_data.transpose()

# %%
gdi_data=pd.read_excel(r'/trend_analysis_dev.xlsx', sheet_name=["2010","2011","2012","2013","2014","2015","2016","2017","2018","2019"])
# print(gdi_data)
gdi_data_0 = {key: gdi_data[key] for key in gdi_data.keys()
       & {'2010'}}

# df_gdi=pd.DataFrame(gdi_data, columns=['rank','Country'])
# arr_0=[]
# for i in range(df_gdi.shape[0]):
#   rank_arr_0=[]
#   for j in df_gdi.loc[i,]:
#     rank_arr_0.append(j)
#   arr_0.append(rank_arr_0)
# print(arr_0)

# %%
from matplotlib import pyplot as plt
import numpy as  np
plt.style.use('seaborn')


year=[1995,2000,2005,2010,2011,2012,2013]

# gdi_mongolia=[0.971,1.009,1.016,1.021,1.017,1.025,1.023]
# gii_mongolia=[0.502,0.449,0.414,0.409,0.407,0.319,0.321]

# gdi_niger=[0.697,0.718,0.741,0.699,0.702,0.714,0.715]
# gii_niger=[0.801,0.797,0.703,0.690,0.683,0.678,0.674]

gdi_uganda=[0.867,0.886,0.884,0.862,0.863,0.866,0.865]
gii_uganda=[0.651,0.644,0.595,0.571,0.56,0.555,0.554]

# gdi_sweden=[1,0.988,0.996,0.996,0.996,1,0.989]
# gii_sweden=[0.09,0.061,0.052,0.05,0.049,0.048,0.047]

# gdi_tajik=[0.861,0.852,0.866,0.803,0.804,0.812,0.822]
# gii_tajik=[0.57,0.419,0.348,0.334,0.33,0.326,0.322]

# gdi_ukraine=[1.003,0.992,1.004,1.012,1.005,1.003,1.003]
# gii_ukraine=[0.48,0.388,0.379,0.334,0.327,0.319,0.313]

# ind_year=[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013]
# gdi_ind=[0.71,0.71,0.71,0.71,0.71,0.73,0.74,0.75,0.75,0.75,0.76,0.76,0.76,0.78,0.78,0.78,0.78,0.79,0.79,0.8,0.8,0.81,0.81,0.81]
# gii_ind=[0.72,0.71,0.71,0.7,0.7,0.69,0.68,0.68,0.66,0.66,0.65,0.65,0.64,0.63,0.63,0.62,0.62,0.61,0.6,0.59,0.59,0.58,0.57,0.57]

# gdi_us=[0.995,0.987,0.992,0.996,0.996,0.994,0.99]
# gii_us=[0.305,0.284,0.263,0.259,0.255,0.25,0.245]

# plt.plot(ind_year,gdi_ind,marker='o')
# plt.plot(ind_year,gii_ind,marker='o')

# plt.plot(year,gdi_us,marker='o')
# plt.plot(year,gii_us,marker='o')

plt.xticks(ticks=[1995,2000,2005,2010,2011,2012,2013], labels=None)
plt.xlabel('years')

# z = np.polyfit(year, gdi_tajik, 1)
# p = np.poly1d(z)
# plt.plot(year,p(year))
plt.plot(year, gdi_uganda, marker='o')

# z = np.polyfit(year, gii_tajik, 1)
# p = np.poly1d(z)
# plt.plot(year,p(year))
plt.plot(year, gii_uganda, marker='o')

plt.title("trends of GDI and GII in Uganda")
plt.tight_layout()
plt.legend(['GDI','GII'])
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as  np
plt.style.use('seaborn')

year=[1995,2000,2005,2010,2011,2012,2013]

ed_sweden=[0.713,	0.827,	0.953,	0.884,	0.881,	0.875,	0.935]
ed_ukraine=[0.648,	0.673,	0.710,	0.775,	0.796,	0.793,	0.796]
ed_us=[0.856,	0.879,	0.868,	0.893,	0.933,	0.936, 0.924]
ed_niger=[0.052,	0.066,	0.081,	0.107,	0.141,	0.149,	0.167]
ed_india=[0.234,	0.255,	0.309,	0.349,	0.412,	0.436,	0.481]

lif_sweden=[	0.943,	0.954,	0.965,	0.975,	0.978,	0.980,	0.982]
lif_ukraine=[0.818,	0.817,	0.822,	0.843,	0.849,	0.855,	0.860]
lif_us=[0.911,	0.915,	0.926,	0.940,	0.942,	0.943,	0.943]
lif_niger=[0.420,	0.471,	0.526,	0.591,	0.602,	0.614,	0.625]
lif_india=[0.631,	0.666,	0.698,	0.734,	0.742,	0.749,	0.755]

gni_sweden=[0.877,	0.895,	0.910,	0.913,	0.918,	0.918,	0.921]
gni_ukraine=[0.597,	0.662,	0.680,	0.683,	0.686,	0.687,	0.684]
gni_us=[0.899,	0.913,	0.920,	0.921,	0.922,	0.924,	0.927]
gni_niger=[0.294,	0.297,	0.236,	0.234,	0.240,	0.239,	0.242]
gni_india=[0.360,	0.401,	0.426,	0.426,	0.425,	0.431,	0.439]

frph_sweden=[	0.691,	0.764,	0.780,	0.823,	0.825,	0.828,	0.831]
frph_ukraine=[	0.529,	0.541,	0.551,	0.557,	0.560, 0.560,	0.561]
frph_us=[	0.559,	0.564,	0.567,	0.565,	0.567,	0.567,	0.569]
frph_niger=[	0.504,	0.504,	0.504,	0.504,	0.504,	0.504,	0.505]
frph_india=[	0.508,	0.509,	0.512,	0.516,	0.518,	0.519,	0.520]

femp_sweden=[	0.604,	0.633,	0.663,	0.653,	0.656,	0.658,	0.661]
femp_ukraine=[	0.550,	0.587,	0.582,	0.605,	0.606,	0.614,	0.615]
femp_us=[	0.622,	0.628,	0.633,	0.643,	0.644,	0.649,	0.649]
femp_niger=[	0.118,	0.133,	0.151,	0.158,	0.161,	0.164,	0.167]
femp_india=[	0.362,	0.392,	0.411,	0.424,	0.428,	0.429,	0.430]

labm_sweden=[	0.638,	0.625,	0.629,	0.632,	0.635,	0.635,	0.639]
labm_ukraine=[	0.604,	0.576,	0.558,	0.557,	0.560,	0.558,	0.564]
labm_us=[	0.661,	0.666,	0.652,	0.637,	0.631,	0.632,	0.627]
labm_niger=[	0.795,	0.796,	0.799,	0.798,	0.798,	0.777,	0.753]
labm_india=[	0.574,	0.567,	0.574,	0.531,	0.522,	0.512,	0.508]

#plt.plot(year,frph_sweden,marker='o')
#plt.plot(year,ed_sweden,marker='o')
#plt.plot(year,lif_sweden,marker='o')
#plt.plot(year,gni_sweden,marker='o')

#plt.plot(year,frph_ukraine,marker='o')
#plt.plot(year,ed_ukraine,marker='o')
#plt.plot(year,lif_ukraine,marker='o')
#plt.plot(year,gni_ukraine,marker='o')

#plt.plot(year,frph_us,marker='o')
#plt.plot(year,ed_us,marker='o')
#plt.plot(year,lif_us,marker='o')
#plt.plot(year,gni_us,marker='o')

#plt.plot(year,frph_niger,marker='o')
#plt.plot(year,ed_niger,marker='o')
#plt.plot(year,lif_niger,marker='o')
#plt.plot(year,gni_niger,marker='o')

#plt.plot(year,frph_india,marker='o')
#plt.plot(year,ed_india,marker='o')
#plt.plot(year,lif_india,marker='o')
#plt.plot(year,gni_india,marker='o')



#//////female empowerment index\\\\\\\\

#plt.plot(year,femp_sweden,marker='o')
#plt.plot(year,ed_sweden,marker='o')
#plt.plot(year,lif_sweden,marker='o')
#plt.plot(year,gni_sweden,marker='o')

#plt.plot(year,femp_ukraine,marker='o')
#plt.plot(year,ed_ukraine,marker='o')
#plt.plot(year,lif_ukraine,marker='o')
#plt.plot(year,gni_ukraine,marker='o')

#plt.plot(year,femp_us,marker='o')
#plt.plot(year,ed_us,marker='o')
#plt.plot(year,lif_us,marker='o')
#plt.plot(year,gni_us,marker='o')

#plt.plot(year,femp_niger,marker='o')
#plt.plot(year,ed_niger,marker='o')
#plt.plot(year,lif_niger,marker='o')
#plt.plot(year,gni_niger,marker='o')

#plt.plot(year,femp_india,marker='o')
#plt.plot(year,ed_india,marker='o')
#plt.plot(year,lif_india,marker='o')
#plt.plot(year,gni_india,marker='o')


#//////Labour market index\\\\\\\\

plt.plot(year,labm_sweden,marker='o')
#plt.plot(year,ed_sweden,marker='o')
plt.plot(year,lif_sweden,marker='o')
#plt.plot(year,gni_sweden,marker='o')

#plt.plot(year,labm_ukraine,marker='o')
#plt.plot(year,ed_ukraine,marker='o')
#plt.plot(year,lif_ukraine,marker='o')
#plt.plot(year,gni_ukraine,marker='o')

#plt.plot(year,labm_us,marker='o')
#plt.plot(year,ed_us,marker='o')
#plt.plot(year,lif_us,marker='o')
#plt.plot(year,gni_us,marker='o')

#plt.plot(year,labm_niger,marker='o')
#plt.plot(year,ed_niger,marker='o')
#plt.plot(year,lif_niger,marker='o')
#plt.plot(year,gni_niger,marker='o')

#plt.plot(year,labm_india,marker='o')
#plt.plot(year,ed_india,marker='o')
#plt.plot(year,lif_india,marker='o')
#plt.plot(year,gni_india,marker='o')


plt.xticks(ticks=[1995,2000,2005,2010,2011,2012,2013], labels=None)
plt.xlabel('years')

#.......female reproductive health index

#plt.title("Sweden: Female Reproductive Health index and Education index")
#plt.title("Sweden: Female Reproductive Health index and Life expectancy index")
#plt.title("Sweden: Female Reproductive Health index and GNI index")

#plt.title("Ukraine: Female Reproductive Health index and Education index")
#plt.title("Ukraine: Female Reproductive Health index and Life expectancy index")
#plt.title("Ukraine: Female Reproductive Health index and GNI index")

#plt.title("US: Female Reproductive Health index and Education index")
#plt.title("US: Female Reproductive Health index and Life expectancy index")
#plt.title("US: Female Reproductive Health index and GNI index")

#plt.title("Niger: Female Reproductive Health index and Education index")
#plt.title("Niger: Female Reproductive Health index and Life expectancy index")
#plt.title("Niger: Female Reproductive Health index and GNI index")

#plt.title("India: Female Reproductive Health index and Education index")
#plt.title("India: Female Reproductive Health index and Life expectancy index")
#plt.title("India: Female Reproductive Health index and GNI index")



#///////female empowerment index\\\\\\\\

#plt.title("Sweden: Female empowerment index and Education index")
#plt.title("Sweden: Female empowerment index and Life expectancy index")
#plt.title("Sweden: Female empowerment index and GNI index")

#plt.title("Ukraine: Female empowerment index and Education index")
#plt.title("Ukraine: Female empowerment index and Life expectancy index")
#plt.title("Ukraine: Female empowerment index and GNI index")

#plt.title("US: Female empowerment index and Education index")
#plt.title("US: Female empowerment index and Life expectancy index")
#plt.title("US: Female empowerment index and GNI index")

#plt.title("Niger: Female empowerment index and Education index")
#plt.title("Niger: Female empowerment index and Life expectancy index")
#plt.title("Niger: Female empowerment index and GNI index")

#plt.title("India: Female empowerment index and Education index")
#plt.title("India: Female empowerment index and Life expectancy index")
#plt.title("India: Female empowerment index and GNI index")


#///////female labour market index\\\\\\\\

#plt.title("Sweden: Female labour market index and Education index")
plt.title("Sweden: Female labour market index and Life expectancy index")
#plt.title("Sweden: Female labour market index and GNI index")

#plt.title("Ukraine: Female labour market index and Education index")
#plt.title("Ukraine: Female labour market index and Life expectancy index")
#plt.title("Ukraine: Female labour market index and GNI index")

#plt.title("US: Female labour market index and Education index")
#plt.title("US: Female labour market index and Life expectancy index")
#plt.title("US: Female labour market index and GNI index")

#plt.title("Niger: Female labour market index and Education index")
#plt.title("Niger: Female labour market index and Life expectancy index")
#plt.title("Niger: Female labour market index and GNI index")

#plt.title("India: Female labour market index and Education index")
#plt.title("India: Female labour market index and Life expectancy index")
#plt.title("India: Female labour market index and GNI index")


plt.tight_layout()
#plt.legend(['Female Reproductive Health index','Education index'])
#plt.legend(['Female Reproductive Health index','Life expectancy index'])
#plt.legend(['Female Reproductive Health index','GNI index'])

#plt.legend(['Female Empowerment index','Education index'])
#plt.legend(['Female Empowerment index','Life expectancy index'])
#plt.legend(['Female Empowerment index','GNI index'])

#plt.legend(['Female Labour market index','Education index'])
plt.legend(['Female Labour market index','Life expectancy index'])
#plt.legend(['Female Labour market index','GNI index'])
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as  np
plt.style.use('seaborn')

year=[1995,2000,2005,2010,2011,2012,2013]

ed_sweden=[0.713,	0.827,	0.953,	0.884,	0.881,	0.875,	0.935]
ed_ukraine=[0.648,	0.673,	0.710,	0.775,	0.796,	0.793,	0.796]
ed_us=[0.856,	0.879,	0.868,	0.893,	0.933,	0.936, 0.924]
ed_niger=[0.052,	0.066,	0.081,	0.107,	0.141,	0.149,	0.167]
ed_india=[0.234,	0.255,	0.309,	0.349,	0.412,	0.436,	0.481]

lif_sweden=[	0.943,	0.954,	0.965,	0.975,	0.978,	0.980,	0.982]
lif_ukraine=[0.818,	0.817,	0.822,	0.843,	0.849,	0.855,	0.860]
lif_us=[0.911,	0.915,	0.926,	0.940,	0.942,	0.943,	0.943]
lif_niger=[0.420,	0.471,	0.526,	0.591,	0.602,	0.614,	0.625]
lif_india=[0.631,	0.666,	0.698,	0.734,	0.742,	0.749,	0.755]

gni_sweden=[0.877,	0.895,	0.910,	0.913,	0.918,	0.918,	0.921]
gni_ukraine=[0.597,	0.662,	0.680,	0.683,	0.686,	0.687,	0.684]
gni_us=[0.899,	0.913,	0.920,	0.921,	0.922,	0.924,	0.927]
gni_niger=[0.294,	0.297,	0.236,	0.234,	0.240,	0.239,	0.242]
gni_india=[0.360,	0.401,	0.426,	0.426,	0.425,	0.431,	0.439]

frph_sweden=[	0.691,	0.764,	0.780,	0.823,	0.825,	0.828,	0.831]
frph_ukraine=[	0.529,	0.541,	0.551,	0.557,	0.560, 0.560,	0.561]
frph_us=[	0.559,	0.564,	0.567,	0.565,	0.567,	0.567,	0.569]
frph_niger=[	0.504,	0.504,	0.504,	0.504,	0.504,	0.504,	0.505]
frph_india=[	0.508,	0.509,	0.512,	0.516,	0.518,	0.519,	0.520]

femp_sweden=[	0.604,	0.633,	0.663,	0.653,	0.656,	0.658,	0.661]
femp_ukraine=[	0.550,	0.587,	0.582,	0.605,	0.606,	0.614,	0.615]
femp_us=[	0.622,	0.628,	0.633,	0.643,	0.644,	0.649,	0.649]
femp_niger=[	0.118,	0.133,	0.151,	0.158,	0.161,	0.164,	0.167]
femp_india=[	0.362,	0.392,	0.411,	0.424,	0.428,	0.429,	0.430]

labm_sweden=[	0.638,	0.625,	0.629,	0.632,	0.635,	0.635,	0.639]
labm_ukraine=[	0.604,	0.576,	0.558,	0.557,	0.560,	0.558,	0.564]
labm_us=[	0.661,	0.666,	0.652,	0.637,	0.631,	0.632,	0.627]
labm_niger=[	0.795,	0.796,	0.799,	0.798,	0.798,	0.777,	0.753]
labm_india=[	0.574,	0.567,	0.574,	0.531,	0.522,	0.512,	0.508]

#//////Labour market index\\\\\\\\

plt.plot(year,labm_sweden,marker='o')
#plt.plot(year,ed_sweden,marker='o')
plt.plot(year,lif_sweden,marker='o')
#plt.plot(year,gni_sweden,marker='o')

#plt.plot(year,labm_ukraine,marker='o')
#plt.plot(year,ed_ukraine,marker='o')
#plt.plot(year,lif_ukraine,marker='o')
#plt.plot(year,gni_ukraine,marker='o')

#plt.plot(year,labm_us,marker='o')
#plt.plot(year,ed_us,marker='o')
#plt.plot(year,lif_us,marker='o')
#plt.plot(year,gni_us,marker='o')

#plt.plot(year,labm_niger,marker='o')
#plt.plot(year,ed_niger,marker='o')
#plt.plot(year,lif_niger,marker='o')
#plt.plot(year,gni_niger,marker='o')

#plt.plot(year,labm_india,marker='o')
#plt.plot(year,ed_india,marker='o')
#plt.plot(year,lif_india,marker='o')
#plt.plot(year,gni_india,marker='o')


plt.xticks(ticks=[1995,2000,2005,2010,2011,2012,2013], labels=None)
plt.xlabel('years')

#.......female reproductive health index

#plt.title("Sweden: Female Reproductive Health index and Education index")
#plt.title("Sweden: Female Reproductive Health index and Life expectancy index")
#plt.title("Sweden: Female Reproductive Health index and GNI index")

#plt.title("Ukraine: Female Reproductive Health index and Education index")
#plt.title("Ukraine: Female Reproductive Health index and Life expectancy index")
#plt.title("Ukraine: Female Reproductive Health index and GNI index")

#plt.title("US: Female Reproductive Health index and Education index")
#plt.title("US: Female Reproductive Health index and Life expectancy index")
#plt.title("US: Female Reproductive Health index and GNI index")

#plt.title("Niger: Female Reproductive Health index and Education index")
#plt.title("Niger: Female Reproductive Health index and Life expectancy index")
#plt.title("Niger: Female Reproductive Health index and GNI index")

#plt.title("India: Female Reproductive Health index and Education index")
#plt.title("India: Female Reproductive Health index and Life expectancy index")
#plt.title("India: Female Reproductive Health index and GNI index")



#///////female empowerment index\\\\\\\\

#plt.title("Sweden: Female empowerment index and Education index")
#plt.title("Sweden: Female empowerment index and Life expectancy index")
#plt.title("Sweden: Female empowerment index and GNI index")

#plt.title("Ukraine: Female empowerment index and Education index")
#plt.title("Ukraine: Female empowerment index and Life expectancy index")
#plt.title("Ukraine: Female empowerment index and GNI index")

#plt.title("US: Female empowerment index and Education index")
#plt.title("US: Female empowerment index and Life expectancy index")
#plt.title("US: Female empowerment index and GNI index")

#plt.title("Niger: Female empowerment index and Education index")
#plt.title("Niger: Female empowerment index and Life expectancy index")
#plt.title("Niger: Female empowerment index and GNI index")

#plt.title("India: Female empowerment index and Education index")
#plt.title("India: Female empowerment index and Life expectancy index")
#plt.title("India: Female empowerment index and GNI index")


#///////female labour market index\\\\\\\\

#plt.title("Sweden: Female labour market index and Education index")
plt.title("Sweden: Female labour market index and Life expectancy index")
#plt.title("Sweden: Female labour market index and GNI index")

#plt.title("Ukraine: Female labour market index and Education index")
#plt.title("Ukraine: Female labour market index and Life expectancy index")
#plt.title("Ukraine: Female labour market index and GNI index")

#plt.title("US: Female labour market index and Education index")
#plt.title("US: Female labour market index and Life expectancy index")
#plt.title("US: Female labour market index and GNI index")

#plt.title("Niger: Female labour market index and Education index")
#plt.title("Niger: Female labour market index and Life expectancy index")
#plt.title("Niger: Female labour market index and GNI index")

#plt.title("India: Female labour market index and Education index")
#plt.title("India: Female labour market index and Life expectancy index")
#plt.title("India: Female labour market index and GNI index")


plt.tight_layout()
#plt.legend(['Female Reproductive Health index','Education index'])
#plt.legend(['Female Reproductive Health index','Life expectancy index'])
#plt.legend(['Female Reproductive Health index','GNI index'])

#plt.legend(['Female Empowerment index','Education index'])
#plt.legend(['Female Empowerment index','Life expectancy index'])
#plt.legend(['Female Empowerment index','GNI index'])

#plt.legend(['Female Labour market index','Education index'])
plt.legend(['Female Labour market index','Life expectancy index'])
#plt.legend(['Female Labour market index','GNI index'])
plt.show()

# %% [markdown]
# # Female Labour market index

# %%
from matplotlib import pyplot as plt
import numpy as  np
plt.style.use('seaborn')

year=[1995,2000,2005,2010,2011,2012,2013]

ed_sweden=[0.713,	0.827,	0.953,	0.884,	0.881,	0.875,	0.935]
ed_ukraine=[0.648,	0.673,	0.710,	0.775,	0.796,	0.793,	0.796]
ed_us=[0.856,	0.879,	0.868,	0.893,	0.933,	0.936, 0.924]
ed_niger=[0.052,	0.066,	0.081,	0.107,	0.141,	0.149,	0.167]
ed_india=[0.234,	0.255,	0.309,	0.349,	0.412,	0.436,	0.481]

lif_sweden=[	0.943,	0.954,	0.965,	0.975,	0.978,	0.980,	0.982]
lif_ukraine=[0.818,	0.817,	0.822,	0.843,	0.849,	0.855,	0.860]
lif_us=[0.911,	0.915,	0.926,	0.940,	0.942,	0.943,	0.943]
lif_niger=[0.420,	0.471,	0.526,	0.591,	0.602,	0.614,	0.625]
lif_india=[0.631,	0.666,	0.698,	0.734,	0.742,	0.749,	0.755]

gni_sweden=[0.877,	0.895,	0.910,	0.913,	0.918,	0.918,	0.921]
gni_ukraine=[0.597,	0.662,	0.680,	0.683,	0.686,	0.687,	0.684]
gni_us=[0.899,	0.913,	0.920,	0.921,	0.922,	0.924,	0.927]
gni_niger=[0.294,	0.297,	0.236,	0.234,	0.240,	0.239,	0.242]
gni_india=[0.360,	0.401,	0.426,	0.426,	0.425,	0.431,	0.439]

# frph_sweden=[	0.691,	0.764,	0.780,	0.823,	0.825,	0.828,	0.831]
# frph_ukraine=[	0.529,	0.541,	0.551,	0.557,	0.560, 0.560,	0.561]
# frph_us=[	0.559,	0.564,	0.567,	0.565,	0.567,	0.567,	0.569]
# frph_niger=[	0.504,	0.504,	0.504,	0.504,	0.504,	0.504,	0.505]
# frph_india=[	0.508,	0.509,	0.512,	0.516,	0.518,	0.519,	0.520]

# femp_sweden=[	0.604,	0.633,	0.663,	0.653,	0.656,	0.658,	0.661]
# femp_ukraine=[	0.550,	0.587,	0.582,	0.605,	0.606,	0.614,	0.615]
# femp_us=[	0.622,	0.628,	0.633,	0.643,	0.644,	0.649,	0.649]
# femp_niger=[	0.118,	0.133,	0.151,	0.158,	0.161,	0.164,	0.167]
# femp_india=[	0.362,	0.392,	0.411,	0.424,	0.428,	0.429,	0.430]

labm_sweden=[	0.591,	0.584,	0.588,	0.589,	0.595,	0.597,	0.602]
labm_ukraine=[	0.54,	0.508,	0.486,	0.484,	0.482,	0.475,	0.484]
labm_us=[	0.579,	0.59,	0.582,	0.575,	0.569,	0.568,	0.563]
labm_niger=[	0.691,	0.689,	0.688,	0.686,	0.685,	0.661,	0.636]
labm_india=[0.306,	0.304,	0.318,	0.257,	0.243,	0.229,	0.225]

plt.figure().set_figheight(15)

plt.title("Sweden")
plot1 = plt.subplot2grid((24, 9), (0, 0), rowspan=6, colspan=9)
plot2 = plt.subplot2grid((24, 9), (7, 0), rowspan=6, colspan=9)
plot3 = plt.subplot2grid((24, 9), (15, 0), rowspan=6, colspan=9)

#//////Labour market index\\\\\\\\

#////Sweden\\\\
# plot1.plot(year,labm_sweden,marker='o')
# plot1.plot(year,ed_sweden,marker='o')
# plot1.legend(['Female Labour market index','Female Education index'])
# plot1.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot1.set_title("Sweden")

# plot2.plot(year,labm_sweden,marker='o')
# plot2.plot(year,lif_sweden,marker='o')
# plot2.legend(['Female Labour market index','Female Life expectancy index'])
# plot2.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot2.set_title("Sweden")

# plot3.plot(year,labm_sweden,marker='o')
# plot3.plot(year,gni_sweden,marker='o')
# plot3.legend(['Female Labour market index','Female GNI index'])
# plot3.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot3.set_title("Sweden")

#////US\\\\
# plot1.plot(year,labm_us,marker='o')
# plot1.plot(year,ed_us,marker='o')
# plot1.legend(['Female Labour market index','Female Education index'])
# plot1.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot1.set_title("US")

# plot2.plot(year,labm_us,marker='o')
# plot2.plot(year,lif_us,marker='o')
# plot2.legend(['Female Labour market index','Female Life expectancy index'])
# plot2.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot2.set_title("US")

# plot3.plot(year,labm_us,marker='o')
# plot3.plot(year,gni_us,marker='o')
# plot3.legend(['Female Labour market index','Female GNI index'])
# plot3.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot3.set_title("US")

#////Ukraine\\\\
# plot1.plot(year,labm_ukraine,marker='o')
# plot1.plot(year,ed_ukraine,marker='o')
# plot1.legend(['Female Labour market index','Female Education index'])
# plot1.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot1.set_title("Ukraine")

# plot2.plot(year,labm_ukraine,marker='o')
# plot2.plot(year,lif_ukraine,marker='o')
# plot2.legend(['Female Labour market index','Female Life expectancy index'])
# plot2.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot2.set_title("Ukraine")

# plot3.plot(year,labm_ukraine,marker='o')
# plot3.plot(year,gni_ukraine,marker='o')
# plot3.legend(['Female Labour market index','Female GNI index'])
# plot3.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot3.set_title("Ukraine")

# #////Niger\\\\
# plot1.plot(year,labm_niger,marker='o')
# plot1.plot(year,ed_niger,marker='o')
# plot1.legend(['Female Labour market index','Female Education index'])
# plot1.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot1.set_title("Niger")

# plot2.plot(year,labm_niger,marker='o')
# plot2.plot(year,lif_niger,marker='o')
# plot2.legend(['Female Labour market index','Female Life expectancy index'])
# plot2.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot2.set_title("Niger")

# plot3.plot(year,labm_niger,marker='o')
# plot3.plot(year,gni_niger,marker='o')
# plot3.legend(['Female Labour market index','Female GNI index'])
# plot3.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot3.set_title("Niger")

# #////India\\\\
plot1.plot(year,labm_india,marker='o')
plot1.plot(year,ed_india,marker='o')
plot1.legend(['Female Labour market index','Female Education index'])
plot1.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
plot1.set_title("India")

plot2.plot(year,labm_india,marker='o')
plot2.plot(year,lif_india,marker='o')
plot2.legend(['Female Labour market index','Female Life expectancy index'])
plot2.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
plot2.set_title("India")

plot3.plot(year,labm_india,marker='o')
plot3.plot(year,gni_india,marker='o')
plot3.legend(['Female Labour market index','Female GNI index'])
plot3.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
plot3.set_title("India")


plt.xlabel('years')


plt.tight_layout()
plt.show()

# %% [markdown]
# # Female empowerment index

# %%
from matplotlib import pyplot as plt
import numpy as  np
plt.style.use('seaborn')

year=[1995,2000,2005,2010,2011,2012,2013]

ed_sweden=[0.713,	0.827,	0.953,	0.884,	0.881,	0.875,	0.935]
ed_ukraine=[0.648,	0.673,	0.710,	0.775,	0.796,	0.793,	0.796]
ed_us=[0.856,	0.879,	0.868,	0.893,	0.933,	0.936, 0.924]
ed_niger=[0.052,	0.066,	0.081,	0.107,	0.141,	0.149,	0.167]
ed_india=[0.234,	0.255,	0.309,	0.349,	0.412,	0.436,	0.481]

lif_sweden=[	0.943,	0.954,	0.965,	0.975,	0.978,	0.980,	0.982]
lif_ukraine=[0.818,	0.817,	0.822,	0.843,	0.849,	0.855,	0.860]
lif_us=[0.911,	0.915,	0.926,	0.940,	0.942,	0.943,	0.943]
lif_niger=[0.420,	0.471,	0.526,	0.591,	0.602,	0.614,	0.625]
lif_india=[0.631,	0.666,	0.698,	0.734,	0.742,	0.749,	0.755]

gni_sweden=[0.877,	0.895,	0.910,	0.913,	0.918,	0.918,	0.921]
gni_ukraine=[0.597,	0.662,	0.680,	0.683,	0.686,	0.687,	0.684]
gni_us=[0.899,	0.913,	0.920,	0.921,	0.922,	0.924,	0.927]
gni_niger=[0.294,	0.297,	0.236,	0.234,	0.240,	0.239,	0.242]
gni_india=[0.360,	0.401,	0.426,	0.426,	0.425,	0.431,	0.439]

# frph_sweden=[	0.691,	0.764,	0.780,	0.823,	0.825,	0.828,	0.831]
# frph_ukraine=[	0.529,	0.541,	0.551,	0.557,	0.560, 0.560,	0.561]
# frph_us=[	0.559,	0.564,	0.567,	0.565,	0.567,	0.567,	0.569]
# frph_niger=[	0.504,	0.504,	0.504,	0.504,	0.504,	0.504,	0.505]
# frph_india=[	0.508,	0.509,	0.512,	0.516,	0.518,	0.519,	0.520]

femp_sweden=[	0.604,	0.633,	0.663,	0.653,	0.656,	0.658,	0.661]
femp_ukraine=[	0.550,	0.587,	0.582,	0.605,	0.606,	0.614,	0.615]
femp_us=[	0.622,	0.628,	0.633,	0.643,	0.644,	0.649,	0.649]
femp_niger=[	0.118,	0.133,	0.151,	0.158,	0.161,	0.164,	0.167]
femp_india=[	0.362,	0.392,	0.411,	0.424,	0.428,	0.429,	0.430]

# labm_sweden=[	0.591,	0.584,	0.588,	0.589,	0.595,	0.597,	0.602]
# labm_ukraine=[	0.54,	0.508,	0.486,	0.484,	0.482,	0.475,	0.484]
# labm_us=[	0.579,	0.59,	0.582,	0.575,	0.569,	0.568,	0.563]
# labm_niger=[	0.691,	0.689,	0.688,	0.686,	0.685,	0.661,	0.636]
# labm_india=[0.306,	0.304,	0.318,	0.257,	0.243,	0.229,	0.225]

plt.figure().set_figheight(15)


plot1 = plt.subplot2grid((24, 9), (0, 0), rowspan=6, colspan=9)
plot2 = plt.subplot2grid((24, 9), (7, 0), rowspan=6, colspan=9)
plot3 = plt.subplot2grid((24, 9), (15, 0), rowspan=6, colspan=9)

#//////Empowerment index\\\\\\\\

#////Sweden\\\\
plot1.plot(year,femp_sweden,marker='o')
plot1.plot(year,ed_sweden,marker='o')
plot1.legend(['Empowerment index','Female Education index'])
plot1.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
plot1.set_title("Sweden")

plot2.plot(year,femp_sweden,marker='o')
plot2.plot(year,lif_sweden,marker='o')
plot2.legend(['Empowerment index','Female Life expectancy index'])
plot2.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
plot2.set_title("Sweden")

plot3.plot(year,femp_sweden,marker='o')
plot3.plot(year,gni_sweden,marker='o')
plot3.legend(['Empowerment index','Female GNI index'])
plot3.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
plot3.set_title("Sweden")

#////US\\\\
# plot1.plot(year,femp_us,marker='o')
# plot1.plot(year,ed_us,marker='o')
# plot1.legend(['Empowerment index','Female Education index'])
# plot1.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot1.set_title("US")

# plot2.plot(year,femp_us,marker='o')
# plot2.plot(year,lif_us,marker='o')
# plot2.legend(['Empowerment index','Female Life expectancy index'])
# plot2.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot2.set_title("US")

# plot3.plot(year,femp_us,marker='o')
# plot3.plot(year,gni_us,marker='o')
# plot3.legend(['Empowerment index','Female GNI index'])
# plot3.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot3.set_title("US")

#////Ukraine\\\\
# plot1.plot(year,femp_ukraine,marker='o')
# plot1.plot(year,ed_ukraine,marker='o')
# plot1.legend(['Empowerment index','Female Education index'])
# plot1.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot1.set_title("Ukraine")

# plot2.plot(year,femp_ukraine,marker='o')
# plot2.plot(year,lif_ukraine,marker='o')
# plot2.legend(['Empowerment index','Female Life expectancy index'])
# plot2.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot2.set_title("Ukraine")

# plot3.plot(year,femp_ukraine,marker='o')
# plot3.plot(year,gni_ukraine,marker='o')
# plot3.legend(['Empowerment index','Female GNI index'])
# plot3.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot3.set_title("Ukraine")

# #////Niger\\\\
# plot1.plot(year,femp_niger,marker='o')
# plot1.plot(year,ed_niger,marker='o')
# plot1.legend(['Empowerment index','Female Education index'])
# plot1.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot1.set_title("Niger")

# plot2.plot(year,femp_niger,marker='o')
# plot2.plot(year,lif_niger,marker='o')
# plot2.legend(['Empowerment index','Female Life expectancy index'])
# plot2.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot2.set_title("Niger")

# plot3.plot(year,femp_niger,marker='o')
# plot3.plot(year,gni_niger,marker='o')
# plot3.legend(['Empowerment index','Female GNI index'])
# plot3.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot3.set_title("Niger")

# #////India\\\\
# plot1.plot(year,femp_india,marker='o')
# plot1.plot(year,ed_india,marker='o')
# plot1.legend(['Empowerment index','Female Education index'])
# plot1.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot1.set_title("India")

# plot2.plot(year,femp_india,marker='o')
# plot2.plot(year,lif_india,marker='o')
# plot2.legend(['Empowerment index','Female Life expectancy index'])
# plot2.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot2.set_title("India")

# plot3.plot(year,femp_india,marker='o')
# plot3.plot(year,gni_india,marker='o')
# plot3.legend(['Empowerment index','Female GNI index'])
# plot3.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot3.set_title("India")


plt.xlabel('years')


plt.tight_layout()
plt.show()

# %% [markdown]
# # Female reproductive health index

# %%
from matplotlib import pyplot as plt
import numpy as  np
plt.style.use('seaborn')

year=[1995,2000,2005,2010,2011,2012,2013]

ed_sweden=[0.713,	0.827,	0.953,	0.884,	0.881,	0.875,	0.935]
ed_ukraine=[0.648,	0.673,	0.710,	0.775,	0.796,	0.793,	0.796]
ed_us=[0.856,	0.879,	0.868,	0.893,	0.933,	0.936, 0.924]
ed_niger=[0.052,	0.066,	0.081,	0.107,	0.141,	0.149,	0.167]
ed_india=[0.234,	0.255,	0.309,	0.349,	0.412,	0.436,	0.481]

lif_sweden=[	0.943,	0.954,	0.965,	0.975,	0.978,	0.980,	0.982]
lif_ukraine=[0.818,	0.817,	0.822,	0.843,	0.849,	0.855,	0.860]
lif_us=[0.911,	0.915,	0.926,	0.940,	0.942,	0.943,	0.943]
lif_niger=[0.420,	0.471,	0.526,	0.591,	0.602,	0.614,	0.625]
lif_india=[0.631,	0.666,	0.698,	0.734,	0.742,	0.749,	0.755]

gni_sweden=[0.877,	0.895,	0.910,	0.913,	0.918,	0.918,	0.921]
gni_ukraine=[0.597,	0.662,	0.680,	0.683,	0.686,	0.687,	0.684]
gni_us=[0.899,	0.913,	0.920,	0.921,	0.922,	0.924,	0.927]
gni_niger=[0.294,	0.297,	0.236,	0.234,	0.240,	0.239,	0.242]
gni_india=[0.360,	0.401,	0.426,	0.426,	0.425,	0.431,	0.439]

frph_sweden=[	0.691,	0.764,	0.780,	0.823,	0.825,	0.828,	0.831]
frph_ukraine=[	0.529,	0.541,	0.551,	0.557,	0.560, 0.560,	0.561]
frph_us=[	0.559,	0.564,	0.567,	0.565,	0.567,	0.567,	0.569]
frph_niger=[	0.504,	0.504,	0.504,	0.504,	0.504,	0.504,	0.505]
frph_india=[	0.508,	0.509,	0.512,	0.516,	0.518,	0.519,	0.520]

# femp_sweden=[	0.604,	0.633,	0.663,	0.653,	0.656,	0.658,	0.661]
# femp_ukraine=[	0.550,	0.587,	0.582,	0.605,	0.606,	0.614,	0.615]
# femp_us=[	0.622,	0.628,	0.633,	0.643,	0.644,	0.649,	0.649]
# femp_niger=[	0.118,	0.133,	0.151,	0.158,	0.161,	0.164,	0.167]
# femp_india=[	0.362,	0.392,	0.411,	0.424,	0.428,	0.429,	0.430]

# labm_sweden=[	0.591,	0.584,	0.588,	0.589,	0.595,	0.597,	0.602]
# labm_ukraine=[	0.54,	0.508,	0.486,	0.484,	0.482,	0.475,	0.484]
# labm_us=[	0.579,	0.59,	0.582,	0.575,	0.569,	0.568,	0.563]
# labm_niger=[	0.691,	0.689,	0.688,	0.686,	0.685,	0.661,	0.636]
# labm_india=[0.306,	0.304,	0.318,	0.257,	0.243,	0.229,	0.225]


plt.figure().set_figheight(15)

plt.title("Sweden")
plot1 = plt.subplot2grid((21, 9), (0, 0), rowspan=6, colspan=9)
plot2 = plt.subplot2grid((21, 9), (6, 0), rowspan=6, colspan=9)
plot3 = plt.subplot2grid((21, 9), (12, 0), rowspan=6, colspan=9)

#//////Female reproductive health index\\\\\\\\

#////Sweden\\\\

# plot1.plot(year,frph_sweden,marker='o')
# plot1.plot(year,ed_sweden,marker='o')
# plot1.legend(['Female reproductive health index','Female Education index'])
# plot1.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot1.set_title("Sweden")

# plot2.plot(year,frph_sweden,marker='o')
# plot2.plot(year,lif_sweden,marker='o')
# plot2.legend(['Female reproductive health index','Female life expectancy index'])
# plot2.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot2.set_title("Sweden")

# plot3.plot(year,frph_sweden,marker='o')
# plot3.plot(year,gni_sweden,marker='o')
# plot3.legend(['Female reproductive health index','Female GNI index'])
# plot3.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot3.set_title("Sweden")

#////US\\\\
# plot1.plot(year,frph_us,marker='o')
# plot1.plot(year,ed_us,marker='o')
# plot1.legend(['Female reproductive health index','Female Education index'])
# plot1.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot1.set_title("US")

# plot2.plot(year,frph_us,marker='o')
# plot2.plot(year,lif_us,marker='o')
# plot2.legend(['Female reproductive health index','Female life expectancy index'])
# plot2.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot2.set_title("US")

# plot3.plot(year,frph_us,marker='o')
# plot3.plot(year,gni_us,marker='o')
# plot3.legend(['Female reproductive health index','Female GNI index'])
# plot3.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot3.set_title("US")


#////Ukraine\\\\

# plot1.plot(year,frph_ukraine,marker='o')
# plot1.plot(year,ed_ukraine,marker='o')
# plot1.legend(['Female reproductive health index','Female Education index'])
# plot1.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot1.set_title("Ukraine")

# plot2.plot(year,frph_ukraine,marker='o')
# plot2.plot(year,lif_ukraine,marker='o')
# plot2.legend(['Female reproductive health index','Female life expectancy index'])
# plot2.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot2.set_title("Ukraine")

# plot3.plot(year,frph_ukraine,marker='o')
# plot3.plot(year,gni_ukraine,marker='o')
# plot3.legend(['Female reproductive health index','Female GNI index'])
# plot3.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot3.set_title("Ukraine")


# #////Niger\\\\

# plot1.plot(year,frph_niger,marker='o')
# plot1.plot(year,ed_niger,marker='o')
# plot1.legend(['Female reproductive health index','Female Education index'])
# plot1.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot1.set_title("Niger")

# plot2.plot(year,frph_niger,marker='o')
# plot2.plot(year,lif_niger,marker='o')
# plot2.legend(['Female reproductive health index','Female life expectancy index'])
# plot2.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot2.set_title("Niger")

# plot3.plot(year,frph_niger,marker='o')
# plot3.plot(year,gni_niger,marker='o')
# plot3.legend(['Female reproductive health index','Female GNI index'])
# plot3.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot3.set_title("Niger")


# #////India\\\\

# plot1.plot(year,frph_india,marker='o')
# plot1.plot(year,ed_india,marker='o')
# plot1.legend(['Female reproductive health index','Female Education index'])
# plot1.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot1.set_title("India")

# plot2.plot(year,frph_india,marker='o')
# plot2.plot(year,lif_india,marker='o')
# plot2.legend(['Female reproductive health index','Female life expectancy index'])
# plot2.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot2.set_title("India")

# plot3.plot(year,frph_india,marker='o')
# plot3.plot(year,gni_india,marker='o')
# plot3.legend(['Female reproductive health index','Female GNI index'])
# plot3.set_xticks(ticks=[1995,2000,2005,2010,2011,2012,2013])
# plot3.set_title("India")


plt.xlabel('years')


plt.tight_layout()
plt.show()
